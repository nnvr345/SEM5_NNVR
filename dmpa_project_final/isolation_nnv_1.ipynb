# %%
from sklearn.ensemble import IsolationForest
import pandas as pd
import numpy as np
import warnings; warnings.filterwarnings('ignore')

# %%
filepath='C:\\Users\\HP\\Desktop\\labs\\dmpa_project_final\\dmpa_1.csv'
df=pd.read_csv(filepath)
df.head()
# Out:
#    id  line_item_quantity  unit_price  pack_price  line_item_value  \
# 0   3                1000        0.03        6.20           6200.0
# 1  15               31920        0.07        3.99         127360.8
# 2  16               38000        0.05        3.20         121600.0
# 3  23                 416        0.02        5.35           2225.6
# 4  44                 135        0.36       32.40           4374.0
#
#    line_item_insurance sub_classification   dosage weight
# 0           240.117626          Pediatric  10mg/ml    358
# 1           240.117626              Adult    150mg   1855
# 2           240.117626              Adult     30mg   7590
# 3           240.117626          Pediatric  10mg/ml    504
# 4           240.117626          Pediatric    200mg    328

# %%
check_cols=['unit_price',
    'line_item_quantity',
    'line_item_value',
    'weight',
    'line_item_insurance']
x_train=df[check_cols]
x_train.head()
# Out:
#    unit_price  line_item_quantity  line_item_value weight  line_item_insurance
# 0        0.03                1000           6200.0    358           240.117626
# 1        0.07               31920         127360.8   1855           240.117626
# 2        0.05               38000         121600.0   7590           240.117626
# 3        0.02                 416           2225.6    504           240.117626
# 4        0.36                 135           4374.0    328           240.117626

# %%
# clf=IsolationForest(n_jobs=6,random_state=23,contamination=0.05)
# clf.fit(x_train)
# y_pred_train = clf.predict(x_train)
# y_pred_train

x_train=x_train.apply(pd.to_numeric,errors='coerce')
x_train=x_train.dropna()
clf=IsolationForest(n_jobs=100,random_state=42,contamination=0.05)
clf.fit(x_train)
y_pred_train=clf.predict(x_train)
y_pred_train
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
pd.value_counts(y_pred_train)
# Out:
#  1    4271
# -1     225
# Name: count, dtype: int64

# %%
x_train.loc[y_pred_train==-1,:]
# Out:
#       unit_price  line_item_quantity  line_item_value   weight  \
# 112         0.20               61021        725539.69   6768.0
# 169         0.56               60784       1018132.00  11179.0
# 198         1.68                5900        297360.00    493.0
# 312         1.51                1320        238682.40    304.0
# 427         0.34               12560        516216.00   3073.0
# ...          ...                 ...              ...      ...
# 7646        0.25               24470        726269.60   6808.0
# 7708        0.16              138974        653177.80  14845.0
# 7724        0.43               69963        906720.48   7819.0
# 7772        0.14               93700        773962.00  12220.0
# 7773        0.06              169447        635426.25   8039.0
#
#       line_item_insurance
# 112           1160.860000
# 169            240.117626
# 198            475.780000
# 312            240.117626
# 427           1011.780000
# ...                   ...
# 7646          1018.230000
# 7708           915.760000
# 7724          1121.610000
# 7772           957.390000
# 7773           786.020000
#
# [225 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.hist(clf.decision_function(x_train), bins=50)
plt.title("Histogram of Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(x_train['line_item_value'], x_train['line_item_quantity'], c=y_pred_train, cmap='viridis')
plt.title("Scatter Plot of Anomalies")
plt.xlabel("Unit Price")
plt.ylabel("Line Item Quantity")
plt.show()

# %%
plt.boxplot(x_train['unit_price'])
plt.title("Box Plot of Unit Price")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_train['unit_price'], x_train['line_item_quantity'], x_train['line_item_value'], c=y_pred_train, cmap='viridis')
ax.set_xlabel('Unit Price')
ax.set_ylabel('Line Item Quantity')
ax.set_zlabel('Line Item Value')
plt.title("3D Scatter Plot of Anomalies")
plt.show()

# %%
cols=['line_item_quantity']
n_train=df[cols]
n_train.head()
# Out:
#    line_item_quantity
# 0                1000
# 1               31920
# 2               38000
# 3                 416
# 4                 135

# %%
n_train=n_train.apply(pd.to_numeric,errors='coerce')
n_train=n_train.dropna()
clf=IsolationForest(n_jobs=100,random_state=42,contamination=0.05)
clf.fit(n_train)
m_pred_train=clf.predict(n_train)
m_pred_train
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
pd.value_counts(m_pred_train)
# Out:
#  1    7477
# -1     388
# Name: count, dtype: int64

# %%
n_train.loc[m_pred_train==-1,:]
# Out:
#       line_item_quantity
# 82                 95500
# 85                 71577
# 308                98400
# 386                83000
# 459               100000
# ...                  ...
# 7818              110000
# 7830              120000
# 7835               71600
# 7860              205243
# 7861              166571
#
# [388 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.hist(clf.decision_function(n_train), bins=50)
plt.title("Histogram of Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()
